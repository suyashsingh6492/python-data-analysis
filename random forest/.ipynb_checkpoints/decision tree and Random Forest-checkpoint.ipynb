# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('kyphosis.csv')
df.head()#no of patient who have desease kyphosis, after 
#he operation was a corrective spinal surgery and the state of frame basically represents whether
#or not the kyphosis condition was absent or present after the operation.
#And the age is the age of the person in months. So this is data on children.
#The number is a number of vertebrae involved in the operation and the start was the number of the first or top most or vertebrae that was operated on
#so target is kyphosis a target absent or present.
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15

# %%
from sklearn.model_selection import train_test_split
x=df.drop('Kyphosis',axis=1)
y=df['Kyphosis']
x_train,x_test,y_train,y_split=train_test_split(x,y,test_size=.3)

# %%
#start off by just training a single decision tree 
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
dtree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions = dtree.predict(x_test)
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_split,predictions))
print(confusion_matrix(y_split,predictions))
# Out:
#               precision    recall  f1-score   support
#
#       absent       1.00      0.87      0.93        23
#      present       0.40      1.00      0.57         2
#
#     accuracy                           0.88        25
#    macro avg       0.70      0.93      0.75        25
# weighted avg       0.95      0.88      0.90        25
#
# [[20  3]
#  [ 0  2]]

# %%
#results compare to a random forced model.
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(n_estimators=100) #the splits being chosen randomly etc..
rfc.fit(x_train,y_train)
rfc_pred = rfc.predict(x_test)

# %%
print(confusion_matrix(y_split,rfc_pred))
print('\n')
print(classification_report(y_split,rfc_pred))
#as data sets gets larger and larger the random force will pretty much always do better than a single decision tree
# Out:
# [[20  3]
#  [ 0  2]]
#
#
#               precision    recall  f1-score   support
#
#       absent       1.00      0.87      0.93        23
#      present       0.40      1.00      0.57         2
#
#     accuracy                           0.88        25
#    macro avg       0.70      0.93      0.75        25
# weighted avg       0.95      0.88      0.90        25

# %%
# pip install pydot     
#install graph viz for visualize single decision tree

# %%
# you would want to invest in people who showed a profile of having a high probability of paying you back. We will try to create a model that will help predict this.
#We will use lending data from 2007-2010
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
loans=pd.read_csv('loan_data.csv')
loans.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# ...

# %%
#Create a histogram of two FICO distributions on top of each other, one for each credit.policy outcome.**
#credit.policy: 1 if the customer meets the credit underwriting criteria of LendingClub.com, and 0 otherwise.
#fico: The FICO credit score of the borrower. 
#not.fully.paid : This is the column we're going to try to predict.
#Create a histogram of two FICO distributions on top of each other, one for each credit.policy outcome.
plt.figure(figsize=(10,6))
loans[loans['credit.policy']==1]['fico'].hist(alpha=0.5,color='blue',bins=30,label='Credit.Policy=1')
loans[loans['credit.policy']==0]['fico'].hist(alpha=0.5,color='red',bins=30,label='Credit.Policy=0')
plt.legend()
plt.xlabel('FICO') #any one for final score of less than around 660 will automatically not meet the credit underwriting criteria of Lending Club dot com.
# Out:
# Text(0.5, 0, 'FICO')

# %%
#not fully paid equals zero which is again or trying to predict 
plt.figure(figsize=(10,6))
loans[loans['not.fully.paid']==1]['fico'].hist(alpha=0.5,color='blue',
                                              bins=30,label='not.fully.paid=1')
loans[loans['not.fully.paid']==0]['fico'].hist(alpha=0.5,color='red',
                                              bins=30,label='not.fully.paid=0')
plt.legend()
plt.xlabel('FICO')#majority of people are actually fully paying off these loans.
# Out:
# Text(0.5, 0, 'FICO')

# %%
plt.figure(figsize=(11,7))
sns.countplot(x='purpose',hue='not.fully.paid',data=loans,palette='Set1') #we can tell that debt consolidation seems to be the most popular reason
#for wanting a loan and then credit card and or other reasons.
# Out:
# <Axes: xlabel='purpose', ylabel='count'>

# %%
#Let's see the trend between FICO score and interest rate. Recreate the following jointplot.*
#here that as your FICO score increases the interest rate you have to pay off that loan tends 
sns.jointplot(x='fico',y='int.rate',data=loans,color='purple')

# %%
#L-M plots to see if the trend differed between not fully paid and credit policy.
plt.figure(figsize=(11,7)) #credit policy cut off marke 660, split up in 2 colum using col,
# behavior is relatively the same whether or not it was fully paid off or on and whether or not they were denied the credit policy.

sns.lmplot(y='int.rate',x='fico',data=loans,hue='credit.policy',col='not.fully.paid',palette='Set1')

# %%
final_data = pd.get_dummies(loans,columns=['purpose'],drop_first=True) #tranform purpose column into dummy

# %%
from sklearn.model_selection import train_test_split
X = final_data.drop('not.fully.paid',axis=1)
y = final_data['not.fully.paid']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
dtree.fit(X_train,y_train)
predictions = dtree.predict(X_test)
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84      2431
#            1       0.21      0.26      0.23       443
#
#     accuracy                           0.73      2874
#    macro avg       0.53      0.54      0.53      2874
# weighted avg       0.76      0.73      0.74      2874

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[1996  435]
#  [ 330  113]]

# %%
from sklearn.ensemble import RandomForestClassifier
#certain point the number of estimators increasing
#won't help you anymore you'll just kind of hover around a particular accuracy score that a low number can be improved.
rfc = RandomForestClassifier(n_estimators=600)
rfc.fit(X_train,y_train)
predictions = rfc.predict(X_test)
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      2431
#            1       0.65      0.02      0.05       443
#
#     accuracy                           0.85      2874
#    macro avg       0.75      0.51      0.48      2874
# weighted avg       0.82      0.85      0.78      2874

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[2425    6]
#  [ 432   11]]

# %%
# Depends what metric you are trying to optimize for. 
# Notice the recall for each class for the models.
# Neither did very well, more feature engineering is needed.
